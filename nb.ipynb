# %% [markdown]
# RSXCANARY-md <img src=x onerror="console.log('RSXFIRE:md-html:'+location.origin)"> <svg onload="console.log('RSXFIRE:md-svg:'+location.origin)"></svg>

# %%
print('x')
# Out:
# RSXCANARY-outhtml <img src=x onerror="console.log('RSXFIRE:out-html:'+location.origin)"><script>console.log('RSXFIRE:out-script:'+location.origin)</script>
# RSXCANARY-exres <img src=x onerror="console.log('RSXFIRE:exres-html:'+location.origin)">
