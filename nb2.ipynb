# %%
print(1)
# Out:
# RSX-a-js-START <a href="javascript:console.log('RSXFIRE:ajs:'+location.origin)">M</a> RSX-a-js-END

# %%
print(1)
# Out:
# RSX-iframe-js-START <iframe src="javascript:console.log('RSXFIRE:iframejs:'+location.origin)"></iframe> RSX-iframe-js-END

# %%
print(1)
# Out:
# RSX-iframe-srcdoc-START <iframe srcdoc="&lt;script&gt;console.log('RSXFIRE:srcdoc:'+location.origin)&lt;/script&gt;"></iframe> RSX-iframe-srcdoc-END

# %%
print(1)
# Out:
# RSX-svg-animate-START <svg><animate onbegin="console.log('RSXFIRE:animate:'+location.origin)" attributeName=x dur=1s></animate></svg> RSX-svg-animate-END

# %%
print(1)
# Out:
# RSX-svg-set-START <svg><set onbegin="console.log('RSXFIRE:set:'+location.origin)"></set></svg> RSX-svg-set-END

# %%
print(1)
# Out:
# RSX-math-mglyph-START <math><mtext><mglyph><img src=x onerror="console.log('RSXFIRE:mglyph:'+location.origin)"></mglyph></mtext></math> RSX-math-mglyph-END

# %%
print(1)
# Out:
# RSX-details-START <details open ontoggle="console.log('RSXFIRE:details:'+location.origin)">M</details> RSX-details-END

# %%
print(1)
# Out:
# RSX-object-START <object data="javascript:console.log('RSXFIRE:object:'+location.origin)"></object> RSX-object-END

# %%
print(1)
# Out:
# RSX-embed-START <embed src="javascript:console.log('RSXFIRE:embed:'+location.origin)"> RSX-embed-END

# %%
print(1)
# Out:
# RSX-input-foc-START <input autofocus onfocus="console.log('RSXFIRE:inputfocus:'+location.origin)"> RSX-input-foc-END

# %%
print(1)
# Out:
# RSX-audio-START <audio src=x onerror="console.log('RSXFIRE:audio:'+location.origin)"></audio> RSX-audio-END

# %%
print(1)
# Out:
# RSX-video-src-START <video><source onerror="console.log('RSXFIRE:videosrc:'+location.origin)"></video> RSX-video-src-END

# %%
print(1)
# Out:
# RSX-marquee-START <marquee onstart="console.log('RSXFIRE:marquee:'+location.origin)">M</marquee> RSX-marquee-END

# %%
print(1)
# Out:
# RSX-form-fa-START <form><button formaction="javascript:console.log('RSXFIRE:formaction:'+location.origin)">M</button></form> RSX-form-fa-END

# %%
print(1)
# Out:
# RSX-style-START <style>x{background:url('javascript:console.log('RSXFIRE:style:'+location.origin)')}</style>M RSX-style-END

# %%
print(1)
# Out:
# RSX-mxss-noembed-START <noembed><img src=x onerror="console.log('RSXFIRE:noembed:'+location.origin)"></noembed> RSX-mxss-noembed-END

# %%
print(1)
# Out:
# RSX-mxss-style-img-START <style><img src=x onerror="console.log('RSXFIRE:styleimg:'+location.origin)"></style> RSX-mxss-style-img-END

# %%
print(1)
# Out:
# RSX-mxss-noscript-START <noscript><p title="</noscript><img src=x onerror='console.log('RSXFIRE:noscript:'+location.origin)'>"> RSX-mxss-noscript-END

# %%
print(1)
# Out:
# RSX-mxss-select-START <select><noembed></select><img src=x onerror="console.log('RSXFIRE:select:'+location.origin)"> RSX-mxss-select-END

# %%
print(1)
# Out:
# RSX-base-foreign-START <svg><foreignObject><iframe src="javascript:console.log('RSXFIRE:foreign:'+location.origin)"></iframe></foreignObject></svg> RSX-base-foreign-END

# %%
print(1)
# Out:
# RSX-a-data-START <a href="data:text/html,&lt;script&gt;1&lt;/script&gt;">Mdata</a> RSX-a-data-END

# %%
print(1)
# Out:
# RSX-img-onerror-ctl-START <img src=x onerror="console.log('RSXFIRE:imgctl:'+location.origin)"> RSX-img-onerror-ctl-END
