# %%
1

# %%
2

# %%
3
# Out:
# RSX-latex $\href{javascript:console.log('RSXFIRE:latex-href:'+location.origin)}{click}$ RSX-latex-end

# %% [markdown]
# RSX-mdmath $\href{javascript:console.log('RSXFIRE:mdmath-href')}{x}$ RSX-mdmath-end

# %%
5

# %%
6
# Out:
# RSX-rw1 <img src='https://example.com/EXT'> RSX-rw2 <img src='/ABS'> RSX-rw3 <img src='//evil.com/PR'> RSX-rw4 <img src='https://raw.githubusercontent.com@evil.com/x'> RSX-rw-end

# %%
7
# Out:
# RSX-css <link rel=stylesheet href='javascript:1'> <div style="width:expression(console.log('RSXFIRE:cssexpr'))">x</div> <style>@import url(javascript:1)</style> RSX-css-end
